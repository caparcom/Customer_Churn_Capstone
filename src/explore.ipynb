# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
main_df = pd.read_csv("../data/raw/Public_School_characteristics_2022-23.csv")
# Out:
# C:\Users\caleb\AppData\Local\Temp\ipykernel_5144\2103675023.py:1: DtypeWarning: Columns (0: LSTREET2) have mixed types. Specify dtype option on import or set low_memory=False.
#   main_df = pd.read_csv("../data/raw/Public_School_characteristics_2022-23.csv")

# %%
main_df.head()
# Out:
#            X        Y  OBJECTID      NCESSCH   SURVYEAR STABR   LEAID  \
# 0 -86.206200  34.2602         1  10000500870  2022-2023    AL  100005
# 1 -86.204900  34.2622         2  10000500871  2022-2023    AL  100005
# 2 -86.220100  34.2733         3  10000500879  2022-2023    AL  100005
# 3 -86.221806  34.2527         4  10000500889  2022-2023    AL  100005
# 4 -86.193300  34.2898         5  10000501616  2022-2023    AL  100005
#
#   ST_LEAID          LEA_NAME                           SCH_NAME  ...  HIALF  \
# 0   AL-101  Albertville City          Albertville Middle School  ...  251.0
# 1   AL-101  Albertville City            Albertville High School  ...  468.0
# 2   AL-101  Albertville City    Albertville Intermediate School  ...  241.0
# 3   AL-101  Albertville City      Albertville Elementary School  ...  236.0
# 4   AL-101  Albertville City  Albertville Kindergarten and PreK  ...  152.0
#
#       HI TRALM TRALF    TR  WHALM  WHALF     WH   LATCOD     LONCOD
# ...

# %%
main_df.shape
# Out:
# (101390, 77)

# %%
pd.set_option('display.max_columns', None)

# %%
main_df.head(1)
# Out:
#          X        Y  OBJECTID      NCESSCH   SURVYEAR STABR   LEAID ST_LEAID  \
# 0 -86.2062  34.2602         1  10000500870  2022-2023    AL  100005   AL-101
#
#            LEA_NAME                   SCH_NAME           LSTREET1 LSTREET2  \
# 0  Albertville City  Albertville Middle School  600 E Alabama Ave      NaN
#
#          LCITY LSTATE   LZIP LZIP4          PHONE CHARTER_TEXT      VIRTUAL  \
# 0  Albertville     AL  35950        (256)878-2341           No  Not Virtual
#
#   GSLO GSHI SCHOOL_LEVEL  STATUS SCHOOL_TYPE_TEXT          SY_STATUS_TEXT  \
# 0   07   08       Middle       1   Regular School  Currently operational
#
#             ULOCALE           NMCNTY  TOTFRL  FRELCH  REDLCH  DIRECTCERT  PK  \
# 0  32-Town: Distant  Marshall County     697     654      43         587 NaN
#
#    KG  G01  G02  G03  G04  G05  G06    G07    G08  G09  G10  G11  G12  G13  \
# 0 NaN  NaN  NaN  NaN  NaN  NaN  NaN  440.0  450.0  NaN  NaN  NaN  NaN  NaN
#
# ...

# %%
sns.scatterplot(data=main_df, x='X', y='Y')
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
# moving the data to the PostGres DB
#from sqlalchemy import create_engine, text 
#from utils import db_connect 

#engine = db_connect()

#main_df.to_sql(
#    'PSD_2022_to_2023',
#    engine,
#    index=False
#)
# Out:
# Connection successful
# 54

# %%
#df_17_18 = pd.read_csv("../data/raw/Public_School_characteristics_2017-18.csv")

#engine = db_connect()

#df_17_18.to_sql(
#    'PSD_2017_to_2018',
#    engine,
#    index=False
#)
# Out:
# C:\Users\caleb\AppData\Local\Temp\ipykernel_5144\453514085.py:1: DtypeWarning: Columns (0: LSTREET3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_17_18 = pd.read_csv("../data/raw/Public_School_characteristics_2017-18.csv")
# Connection successful
# 370

# %%
#df_18_19 = pd.read_csv("../data/raw/Public_School_characteristics_2018-19.csv")

#engine = db_connect()

#df_18_19.to_sql(
#    'PSD_2018_to_2019',
#    engine,
#    index=False
#)
# Out:
# Connection successful
# 360

# %%
#df_20_21 = pd.read_csv("../data/raw/Public_School_characteristics_2020-21.csv")

#engine = db_connect()

#df_20_21.to_sql(
#    'PSD_2020_to_2021',
#    engine,
#    index=False
#)
# Out:
# C:\Users\caleb\AppData\Local\Temp\ipykernel_5144\2195931422.py:1: DtypeWarning: Columns (0: LSTREET2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_20_21 = pd.read_csv("../data/raw/Public_School_characteristics_2020-21.csv")
# Connection successful
# 363

# %%
#df_21_22 = pd.read_csv("../data/raw/Public_School_characteristics_2021-22.csv")

#engine = db_connect()

#df_21_22.to_sql(
#    'PSD_2021_to_2022',
#    engine,
#    index=False
#)
# Out:
# C:\Users\caleb\AppData\Local\Temp\ipykernel_5144\1004287788.py:1: DtypeWarning: Columns (0: LSTREET2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_21_22 = pd.read_csv("../data/raw/Public_School_characteristics_2021-22.csv")
# Connection successful
# 125
